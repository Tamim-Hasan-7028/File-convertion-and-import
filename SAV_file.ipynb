# %% [markdown]
# ## To read .sav file, we need to install 'pyreadstat' first.

# %%
# !pip install pyreadstat
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 11.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
a=pd.read_spss('/content/drive/MyDrive/DataCamp/Data/Tourist_2.sav')
a.head()
# Out:
#     ID  Q1_age Q2_gender Q3_marital_status  Q4_fam_member  \
# 0  1.0    24.0      male         unmarried            3.0
# 1  2.0    30.0      male         unmarried            5.0
# 2  3.0    21.0      male         unmarried            5.0
# 3  4.0    30.0      male         unmarried            5.0
# 4  5.0    22.0      male         unmarried            4.0
#
#   Q5_edu_qualification Q6_occupation Q7_visite_kuakata Q8_room_available  \
# 0     higher education       student                 2               yes
# 1     higher education       student                 2               yes
# 2     higher education       student                 3               yes
# 3     higher education      business                 3               yes
# 4     higher education       student                 0               yes
#
#   Q9_hotel_quality  ... Q12_food_price Q13_behave_local Q14_behave_driver  \
# 0          neutral  ...      very high         moderate          very bad
# ...
